# %%
import pandas as pd
import numpy as np 
import seaborn as sns  
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df=pd.read_csv("C:/Users/admin/Desktop/F_Project/yield_df.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     Area         Item  Year  crop_yield  \
# 0           0  Albania        Maize  1990       36613
# 1           1  Albania     Potatoes  1990       66667
# 2           2  Albania  Rice, paddy  1990       23333
# 3           3  Albania      Sorghum  1990       12500
# 4           4  Albania     Soybeans  1990        7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                           1485              121.0     16.37
# 1                           1485              121.0     16.37
# 2                           1485              121.0     16.37
# 3                           1485              121.0     16.37
# 4                           1485              121.0     16.37

# %%
df.drop('Unnamed: 0', axis=1, inplace=True, errors='ignore')

# %%
df.head()
# Out:
#       Area         Item  Year  crop_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990       36613                           1485
# 1  Albania     Potatoes  1990       66667                           1485
# 2  Albania  Rice, paddy  1990       23333                           1485
# 3  Albania      Sorghum  1990       12500                           1485
# 4  Albania     Soybeans  1990        7000                           1485
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   crop_yield                     28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  int64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# crop_yield                       0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
# df.duplicated().sum()

# %%
# df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#                Year     crop_yield  average_rain_fall_mm_per_year  \
# count  28242.000000   28242.000000                    28242.00000
# mean    2001.544296   77053.332094                     1149.05598
# std        7.051905   84956.612897                      709.81215
# min     1990.000000      50.000000                       51.00000
# 25%     1995.000000   19919.250000                      593.00000
# 50%     2001.000000   38295.000000                     1083.00000
# 75%     2008.000000  104676.750000                     1668.00000
# max     2013.000000  501412.000000                     3240.00000
#
#        pesticides_tonnes      avg_temp
# count       28242.000000  28242.000000
# mean        37076.909344     20.542627
# std         59958.784665      6.312051
# min             0.040000      1.300000
# 25%          1702.000000     16.702500
# 50%         17529.440000     21.510000
# 75%         48687.880000     26.000000
# max        367778.000000     30.650000

# %%
#Data Visualization
sns.histplot(df['avg_temp'], bins=30, kde=True)

# sns.boxplot(x=df['avg_temp'])
# sns.scatterplot(x=df['avg_temp'], y=df['crop_yield'])
# Out:
# <Axes: xlabel='avg_temp', ylabel='Count'>

# %%
sns.histplot(df['average_rain_fall_mm_per_year'], bins=30, kde=True)
# Out:
# <Axes: xlabel='average_rain_fall_mm_per_year', ylabel='Count'>

# %%
df_numeric = df.select_dtypes(include=['number'])
sns.heatmap(df_numeric.corr(), annot=True)
plt.show()

# %%
len(df['Area'].unique())
# Out:
# 101

# %%
# plt.figure(figsize=(15,30))
# sns.countplot(y=df['Area'])
# plt.show()
# sns.countplot(x="Area", data=df)

# %%
# plt.figure(figsize=(20,5))
# # sns.countplot(y=df['Item'])
# # plt.show()
# sns.countplot(x='Item', data=df)

# %%
(df['Area'].value_counts()<400).sum()
# Out:
# 88

# %%
country=df['Area'].unique()
yield_per_country=[]
for state in country:
    yield_per_country.append(df[df['Area']==state]['crop_yield'].sum())

# %%
yield_per_country
# Out:
# [5711536,
#  6711464,
#  5722563,
#  32864032,
#  4524100,
#  109111062,
#  10852258,
#  4608380,
#  4384717,
#  4443889,
#  15440318,
#  4704812,
#  8442270,
#  470651,
#  167550306,
#  6263075,
#  6083337,
#  7031146,
#  10717883,
#  34706922,
#  4255627,
#  20561214,
#  26927138,
#  6083167,
#  10701651,
#  25312166,
#  21315591,
#  36828848,
#  16855944,
#  1452416,
#  3595638,
#  6210668,
#  15790618,
#  38780463,
#  9260371,
#  14571925,
#  16508723,
#  7975743,
#  8361103,
#  8619194,
#  10920131,
#  8824110,
#  327420324,
#  69193506,
#  10984722,
#  9104030,
#  32280700,
#  19698007,
#  124470912,
#  9965212,
#  14391737,
#  3698588,
#  6956804,
#  4258932,
#  9016288,
#  4174348,
#  6103523,
#  8346715,
#  7934982,
#  15106720,
#  4465841,
#  12684212,
#  130788528,
#  1645100,
#  22173010,
#  6964027,
#  3165475,
#  4113713,
#  14086433,
#  17657728,
#  12819227,
#  12316327,
#  6721305,
#  73897434,
#  10729929,
#  15201910,
#  6564711,
#  12154347,
#  5995626,
# ...

# %%
#YIELD PER COUNTRY
plt.figure(figsize=(15,20))
sns.barplot(x=yield_per_country, y=country)
plt.show()

# %%
crops=df['Item'].unique()
yield_per_crop=[]
for crop in crops:
    yield_per_crop.append(df[df['Item']==crop]['crop_yield'].sum())

# %%
#EACH CROP YIELDING
plt.figure(figsize=(10,5))
sns.barplot(y=crops, x=yield_per_crop)
plt.show()

# %%
df.head()
# Out:
#       Area         Item  Year  crop_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990       36613                           1485
# 1  Albania     Potatoes  1990       66667                           1485
# 2  Albania  Rice, paddy  1990       23333                           1485
# 3  Albania      Sorghum  1990       12500                           1485
# 4  Albania     Soybeans  1990        7000                           1485
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'crop_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
col=[ 'Year', 'average_rain_fall_mm_per_year','pesticides_tonnes', 'avg_temp','Area', 'Item','crop_yield',]

# %%
df=df[col]

# %%
df.head()
# Out:
#    Year  average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp     Area  \
# 0  1990                           1485              121.0     16.37  Albania
# 1  1990                           1485              121.0     16.37  Albania
# 2  1990                           1485              121.0     16.37  Albania
# 3  1990                           1485              121.0     16.37  Albania
# 4  1990                           1485              121.0     16.37  Albania
#
#           Item  crop_yield
# 0        Maize       36613
# 1     Potatoes       66667
# 2  Rice, paddy       23333
# 3      Sorghum       12500
# 4     Soybeans        7000

# %%
X=df.drop('crop_yield',axis=1)
y=df['crop_yield']

# %%
X.shape
# Out:
# (28242, 6)

# %%
y.shape
# Out:
# (28242,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=0, shuffle=True)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

ohe=OneHotEncoder(drop='first')
scale=StandardScaler()

preprocesser=ColumnTransformer(
    transformers = [
        ('StandardScale', scale, [0,1,2,3]),
        ('OneHotEncode',ohe, [4,5])
    ], 
    remainder = 'passthrough'
)

# %%
X_train_dummy=preprocesser.fit_transform(X_train)
X_test_dummy=preprocesser.fit_transform(X_test)

# %%
preprocesser.get_feature_names_out(col[:-1])
# Out:
# array(['StandardScale__Year',
#        'StandardScale__average_rain_fall_mm_per_year',
#        'StandardScale__pesticides_tonnes', 'StandardScale__avg_temp',
#        'OneHotEncode__Area_Algeria', 'OneHotEncode__Area_Angola',
#        'OneHotEncode__Area_Argentina', 'OneHotEncode__Area_Armenia',
#        'OneHotEncode__Area_Australia', 'OneHotEncode__Area_Austria',
#        'OneHotEncode__Area_Azerbaijan', 'OneHotEncode__Area_Bahamas',
#        'OneHotEncode__Area_Bahrain', 'OneHotEncode__Area_Bangladesh',
#        'OneHotEncode__Area_Belarus', 'OneHotEncode__Area_Belgium',
#        'OneHotEncode__Area_Botswana', 'OneHotEncode__Area_Brazil',
#        'OneHotEncode__Area_Bulgaria', 'OneHotEncode__Area_Burkina Faso',
#        'OneHotEncode__Area_Burundi', 'OneHotEncode__Area_Cameroon',
#        'OneHotEncode__Area_Canada',
#        'OneHotEncode__Area_Central African Republic',
#        'OneHotEncode__Area_Chile', 'OneHotEncode__Area_Colombia',
# ...

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor  # Install using: pip install xgboost
from sklearn.metrics import mean_absolute_error, r2_score, accuracy_score

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Decision Tree':DecisionTreeRegressor(),
    'KNN':KNeighborsRegressor(),    
    "Gradient Boosting": GradientBoostingRegressor(),
    "XGBoost Regressor": XGBRegressor() 
}
for name, md in models.items():
    md.fit(X_train_dummy, y_train)
    y_pred=md.predict(X_test_dummy)
    print(f"{name}:mae:{mean_absolute_error(y_test, y_pred)} score:{r2_score(y_test, y_pred)}")
    # print(mean_absolute_error(y_test, y_pred))
    # print(r2_score(y_test, y_pred))
# Out:
# LinearRegression:mae:29259.381655374033 score:0.7597216038270783
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265453683310.70703, tolerance: 16161857296.835384
#   model = cd_fast.sparse_enet_coordinate_descent(
# Lasso:mae:29239.822630034334 score:0.7597277263201012
# Ridge:mae:29205.109384140254 score:0.7596305988733623
# Decision Tree:mae:7759.214374225527 score:0.9392019440311344
# KNN:mae:4443.160948840503 score:0.9862461636667087
# Gradient Boosting:mae:26254.851939467855 score:0.7580528115545689
# XGBoost Regressor:mae:10627.9677734375 score:0.9485090970993042

# %%
# algorithms = ['Linear Regression', 'Lasso', 'Ridge', 'Decision Tree', 'KNN', 'Gradient Boosting', 'XGBoost']

# # MAE values
# mae_values = [29897, 29883, 29852, 5427, 4693, 25554, 10384]

# plt.figure(figsize=(7, 5))
# sns.barplot(y=algorithms, x=mae_values, palette="Blues_r")

# plt.xlabel("Mean Absolute Error (MAE)")
# plt.ylabel("Algorithms")
# plt.title("Algorithm Comparison - MAE")
# plt.show()

algorithms = ['Linear Regression', 'Lasso', 'Ridge', 'Decision Tree', 'KNN', 'Gradient Boosting', 'XGBoost']
mae_values = [29897, 29883, 29852, 5427, 4693, 25554, 10384]

plt.figure(figsize=(7, 5))
plt.plot(algorithms, mae_values, marker="o", linestyle="-", color="green", linewidth=2)

plt.xlabel("Algorithms")
plt.ylabel("Mean Absolute Error (MAE)")
plt.title("Algorithm Comparison - MAE")
plt.grid(True, linestyle="--", alpha=0.7)

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# # R² Scores
r2_scores = [0.7472, 0.7473, 0.7472, 0.9692, 0.9845, 0.7545, 0.9514]

plt.figure(figsize=(7, 5))
plt.plot(algorithms, r2_scores, marker="o", linestyle="-", color="green", linewidth=2)

plt.xlabel("Algorithms")
plt.ylabel("R² Score")
plt.title("Algorithm Comparison - R² Score")
plt.grid(True, linestyle="--", alpha=0.7)

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# plt.figure(figsize=(8, 5))
# sns.scatterplot(x=mae_values, y=r2_scores, hue=algorithms, s=150, palette="viridis")

# plt.xlabel("Mean Absolute Error (MAE)")
# plt.ylabel("R² Score")
# plt.title("Comparison of Models: MAE vs R²")
# plt.legend(title="Algorithm")
# plt.grid(True)

# plt.show()

mae_values = [29897, 29883, 29852, 5427, 4693, 25554, 10384]
r2_scores = [0.7472, 0.7473, 0.7472, 0.9692, 0.9845, 0.7545, 0.9514]
algorithms = ['Linear Regression', 'Lasso', 'Ridge', 'Decision Tree', 'KNN', 'Gradient Boosting', 'XGBoost']

# Create figure
plt.figure(figsize=(8, 5))

# Scatter Plot
sns.scatterplot(x=mae_values, y=r2_scores, hue=algorithms, s=150, palette="viridis", edgecolor="black")

# Regression Line (Trend)
sns.regplot(x=mae_values, y=r2_scores, scatter=False, color='red', ci=None, line_kws={"linestyle": "dashed"})

# Labels & Title
plt.xlabel("Mean Absolute Error (MAE)")
plt.ylabel("R² Score")
plt.title("Comparison of Models: MAE vs R²")
plt.legend(title="Algorithm")
plt.grid(True)

plt.show()

# %%
dtr=KNeighborsRegressor()
dtr.fit(X_train_dummy, y_train)
dtr.predict(X_test_dummy)
# Out:
# array([ 31871. ,  89631.8,  41160.8, ..., 167156.2,  89670.4,  77013.8])

# %%
#Predictive systems

# %%
def prediction(Year, average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp, Area, Item):
    features=np.array([[Year, average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp, Area, Item]],dtype=object)
    transform_features=preprocesser.transform(features)
    predicted_yield=dtr.predict(transform_features).reshape(-1,1)
    return predicted_yield[0][0]

# %%
result=prediction(1990, 1485.0,121.0,16.37,'India','Maize')
# Out:
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# 29541.0

# %%
import pickle
pickle.dump(dtr, open("dtr.pkl","wb"))
pickle.dump(preprocesser, open("preprocesser.pkl","wb"))
